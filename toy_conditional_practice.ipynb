# %%
import numpy as np
import os,re
import sklearn.datasets as skd
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Input
import time
import matplotlib.pyplot as plt

import tensorflow_probability as tfp
tfb = tfp.bijectors
tfd = tfp.distributions

# %%
class MLP_ODE(keras.Model):
    """Multi-layer NN ode_fn."""
    def __init__(self, num_hidden, num_layers, num_output,num_cond=2,name='mlp_ode'):
        super(MLP_ODE, self).__init__()
        self._num_hidden = num_hidden
        self._num_output = num_output
        self._num_layers = num_layers
        self._num_cond = num_cond
        self._modules = []
        
        #Fully connected layers with tanh activation and linear output
        self._modules.append(Input(shape=(1+self._num_output+self._num_cond))) #time is part of the inputs
        for _ in range(self._num_layers - 1):
            self._modules.append(layers.Dense(self._num_hidden,activation='tanh'))
            
        self._modules.append(layers.Dense(self._num_output,activation=None))
        self._model = keras.Sequential(self._modules)

        if self._num_cond > 1:
            #In more dimensiona, is useful to feed the conditional distributions after passing through an independent network model
            self._cond_model = keras.Sequential(
                [
                    Input(shape=(self._num_cond)),
                    layers.Dense(self._num_hidden,activation='relu'),
                    layers.Dense(self._num_cond,activation=None),
                ])
        
    @tf.function
    def call(self, t, data,conditional_input=None):
        if self._num_cond==1:
            #No network for a single feature
            cond_transform=tf.cast(conditional_input,dtype=tf.float32)
        else:
            cond_transform = self._cond_model(conditional_input)
            
        t = t*tf.ones([data.shape[0],1])
        inputs = tf.concat([t, data,cond_transform], -1)
        return self._model(inputs)
    

def make_bijector_kwargs(bijector, name_to_kwargs):
    #Hack to pass the conditional information through all the bijector layers
    if hasattr(bijector, 'bijectors'):
        return {b.name: make_bijector_kwargs(b, name_to_kwargs) for b in bijector.bijectors}
    else:
        for name_regex, kwargs in name_to_kwargs.items():
            if re.match(name_regex, bijector.name):
                return kwargs
    return {}

        
class FFJORD(keras.Model):
    def __init__(self, stacked_mlps, batch_size,num_output,name='FFJORD'):
        super(FFJORD, self).__init__()
        self._num_output=num_output
        self._batch_size = batch_size 
        ode_solve_fn = tfp.math.ode.DormandPrince(atol=1e-5).solve
        #Gaussian noise to trace solver
        trace_augmentation_fn = tfb.ffjord.trace_jacobian_hutchinson
        #trace_augmentation_fn = tfb.ffjord.trace_jacobian_exact
        
        bijectors = []
        for imlp,mlp in enumerate(stacked_mlps):
            ffjord = tfb.FFJORD(
                state_time_derivative_fn=mlp,
                ode_solve_fn=ode_solve_fn,
                trace_augmentation_fn=trace_augmentation_fn,
                name='bijector{}'.format(imlp) #Bijectors need to be names to receive conditional inputs
            )
            bijectors.append(ffjord)

        #Reverse the bijector order
        self.chain = tfb.Chain(list(reversed(bijectors)))

        self.loss_tracker = keras.metrics.Mean(name="loss")
        #Determien the base distribution
        self.base_distribution = tfp.distributions.MultivariateNormalDiag(
            loc=self._num_output*[0.0], scale_diag=self._num_output*[1.0]
        )
        
        self.flow=self.Transform()
        self._variables = self.flow.variables
        
    @property
    def metrics(self):
        """List of the model's metrics.
        We make sure the loss tracker is listed as part of `model.metrics`
        so that `fit()` and `evaluate()` are able to `reset()` the loss tracker
        at the start of each epoch and at the start of an `evaluate()` call.
        """
        return [self.loss_tracker]
    
    @tf.function
    def call(self, inputs, conditional_input=None):
        kwargs = make_bijector_kwargs(self.flow.bijector,{'bijector.': {'conditional_input':conditional_input }})
        return self.flow.bijector.forward(inputs,**kwargs)
    
    @tf.function
    def conditional_inverse(self, inputs, conditional_input):
        kwargs = make_bijector_kwargs(self.flow.bijector,{'bijector.' : {'conditional_input' : conditional_input}})
        return self.flow.bijector.inverse(inputs, **kwargs)
            
    def Transform(self):        
        return tfd.TransformedDistribution(distribution=self.base_distribution, bijector=self.chain)

    
    @tf.function
    def log_loss(self,_x,_c):
        loss = -tf.reduce_mean(self.flow.log_prob(
            _x,
            bijector_kwargs=make_bijector_kwargs(
                self.flow.bijector, {'bijector.': {'conditional_input': _c}})                                      
        ))
        
        return loss
    
    @tf.function
    def conditional_prob(self,_x,_c):
        return self.flow.prob(
            _x,
            bijector_kwargs=make_bijector_kwargs(
                self.flow.bijector, {'bijector.': {'conditional_input': _c}})                                      
        )
    
    
    @tf.function()
    def train_step(self, values):
        #Full shape needs to be given when using tf.dataset
        data = values[:self._batch_size,:self._num_output]
        cond = values[:self._batch_size,self._num_output:]
        data.set_shape((self._batch_size,self._num_output))
        cond.set_shape((self._batch_size,cond.shape[1]))

        with tf.GradientTape() as tape:
            loss = self.log_loss(data,cond)
            
        g = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(g, self.trainable_variables))
        self.loss_tracker.update_state(loss)

        return {"loss": self.loss_tracker.result()}
    
    @tf.function
    def test_step(self, values):
        data = values[:self._batch_size,:self._num_output]
        cond = values[:self._batch_size,self._num_output:]
        data.set_shape((self._batch_size,self._num_output))
        cond.set_shape((self._batch_size,cond.shape[1]))
        
        loss = self.log_loss(data,cond)
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

# %%
samples
# Out:
# array([[-0.01943039,  0.09027786,  1.        ],
#        [-0.75599146, -0.35100138,  1.        ],
#        [-0.5122746 , -0.88773346,  1.        ],
#        ...,
#        [-3.300355  , -2.4843159 ,  0.        ],
#        [-2.2547748 , -3.375809  ,  0.        ],
#        [-3.342115  , -3.1241198 ,  0.        ]], dtype=float32)

# %%
LR = 1e-2
NUM_EPOCHS = 20
STACKED_FFJORDS = 4 #Number of stacked transformations
NUM_LAYERS = 8 #Hiddden layers per bijector
NUM_OUTPUT = 2 #Output dimension
NUM_HIDDEN = 4*NUM_OUTPUT #Hidden layer node size
NUM_COND = 1 #Number of conditional dimensions

#Target dataset: half moon
DATASET_SIZE = 1024 * 8
BATCH_SIZE = 256 

samples= np.concatenate(
(
    np.random.normal(0.,0.5,(DATASET_SIZE//2,2)),
    np.random.normal(-3.,0.5,(DATASET_SIZE//2,2)),
),0).astype(np.float32)

constrain = np.concatenate(
    (np.ones((DATASET_SIZE//2,1)),np.zeros((DATASET_SIZE//2,1))),0).astype(np.float32)


samples = np.concatenate([samples,constrain],-1) #Last dimensions are the conditional values

print(samples.shape, constrain.shape)

# Example of np.concatenate(xxx, -1):
# a = np.array([[1, 2], [3, 4]])
# b = np.array([[5, 6], [7, 8]])
# np.concatenate([a, b], -1)
# >>> array([[1, 2, 5, 6],
#.           [3, 4, 7, 8]])


#Stack of bijectors 
stacked_mlps = []
for _ in range(STACKED_FFJORDS):
    mlp_model = MLP_ODE(NUM_HIDDEN, NUM_LAYERS, NUM_OUTPUT,NUM_COND)
    stacked_mlps.append(mlp_model)

#Create the model
model = FFJORD(stacked_mlps,BATCH_SIZE,NUM_OUTPUT)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=LR))

history = model.fit(
    samples,
    batch_size=BATCH_SIZE,
    epochs=NUM_EPOCHS,
    verbose=1,
)

NSAMPLES = DATASET_SIZE
#Sample the learned distribution
transformed = model.flow.sample(
    NSAMPLES,
    bijector_kwargs=make_bijector_kwargs(
        model.flow.bijector, {'bijector.': {'conditional_input': constrain}})
)

transformed_first = model.flow.sample(
    NSAMPLES,
    bijector_kwargs=make_bijector_kwargs(
        model.flow.bijector, {'bijector.': {'conditional_input': np.ones((NSAMPLES,1),dtype=np.float32)}})
)

transformed_second = model.flow.sample(
    NSAMPLES,
    bijector_kwargs=make_bijector_kwargs(
        model.flow.bijector, {'bijector.': {'conditional_input': np.zeros((NSAMPLES,1),dtype=np.float32)}})
)

#Plotting    
fig = plt.figure(figsize=(8, 6))
plt.subplot(211)    
plt.scatter(transformed[:, 0], transformed[:, 1], color="r")
plt.subplot(212)
plt.scatter(transformed_first[:, 0], transformed_first[:, 1], color="r")
plt.scatter(transformed_second[:, 0], transformed_second[:, 1], color="b")

plot_folder = '../plots'
if not os.path.exists(plot_folder):
    os.makedirs(plot_folder)

fig.savefig('{}/conditional_gaus.pdf'.format(plot_folder))
# Out:
# (8192, 3) (8192, 1)
# Epoch 1/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [92], in <module>
#      42 model = FFJORD(stacked_mlps,BATCH_SIZE,NUM_OUTPUT)
#      43 model.compile(optimizer=keras.optimizers.Adam(learning_rate=LR))
# ---> 45 history = model.fit(
#      46     samples,
#      47     batch_size=BATCH_SIZE,
#      48     epochs=NUM_EPOCHS,
#      49     verbose=1,
#      50 )
#      52 NSAMPLES = DATASET_SIZE
#      53 #Sample the learned distribution
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/keras/engine/training.py:1216, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1209 with tf.profiler.experimental.Trace(
#    1210     'train',
#    1211     epoch_num=epoch,
#    1212     step_num=step,
#    1213     batch_size=batch_size,
#    1214     _r=1):
#    1215   callbacks.on_train_batch_begin(step)
# -> 1216   tmp_logs = self.train_function(iterator)
#    1217   if data_handler.should_sync:
#    1218     context.async_wait()
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:910, in Function.__call__(self, *args, **kwds)
#     907 compiler = "xla" if self._jit_compile else "nonXla"
#     909 with OptionalXlaContext(self._jit_compile):
# --> 910   result = self._call(*args, **kwds)
#     912 new_tracing_count = self.experimental_get_tracing_count()
#     913 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:958, in Function._call(self, *args, **kwds)
#     955 try:
#     956   # This is the first call of __call__, so we have to initialize.
#     957   initializers = []
# --> 958   self._initialize(args, kwds, add_initializers_to=initializers)
#     959 finally:
#     960   # At this point we know that the initialization is complete (or less
#     961   # interestingly an exception was raised) so we no longer need a lock.
#     962   self._lock.release()
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:780, in Function._initialize(self, args, kwds, add_initializers_to)
#     777 self._lifted_initializer_graph = lifted_initializer_graph
#     778 self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     779 self._concrete_stateful_fn = (
# --> 780     self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     781         *args, **kwds))
#     783 def invalid_creator_scope(*unused_args, **unused_kwds):
#     784   """Disables variable creation."""
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/function.py:3157, in Function._get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3155   args, kwargs = None, None
#    3156 with self._lock:
# -> 3157   graph_function, _ = self._maybe_define_function(args, kwargs)
#    3158 return graph_function
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/function.py:3557, in Function._maybe_define_function(self, args, kwargs)
#    3553   return self._define_function_with_shape_relaxation(
#    3554       args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3556 self._function_cache.missed.add(call_context_key)
# -> 3557 graph_function = self._create_graph_function(args, kwargs)
#    3558 self._function_cache.primary[cache_key] = graph_function
#    3560 return graph_function, filtered_flat_args
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/function.py:3392, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3387 missing_arg_names = [
#    3388     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    3389 ]
#    3390 arg_names = base_arg_names + missing_arg_names
#    3391 graph_function = ConcreteFunction(
# -> 3392     func_graph_module.func_graph_from_py_func(
#    3393         self._name,
#    3394         self._python_function,
#    3395         args,
#    3396         kwargs,
#    3397         self.input_signature,
#    3398         autograph=self._autograph,
#    3399         autograph_options=self._autograph_options,
#    3400         arg_names=arg_names,
#    3401         override_flat_arg_shapes=override_flat_arg_shapes,
#    3402         capture_by_value=self._capture_by_value),
#    3403     self._function_attributes,
#    3404     function_spec=self.function_spec,
#    3405     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    3406     # scope. This is not the default behavior since it gets used in some
#    3407     # places (like Keras) where the FuncGraph lives longer than the
#    3408     # ConcreteFunction.
#    3409     shared_func_graph=False)
#    3410 return graph_function
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py:1143, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1140 else:
#    1141   _, original_func = tf_decorator.unwrap(python_func)
# -> 1143 func_outputs = python_func(*func_args, **func_kwargs)
#    1145 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1146 # TensorArrays and `None`s.
#    1147 func_outputs = nest.map_structure(convert, func_outputs,
#    1148                                   expand_composites=True)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:672, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     668 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     669   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     670   # the function a weak reference to itself to avoid a reference cycle.
#     671   with OptionalXlaContext(compile_with_xla):
# --> 672     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673   return out
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py:1118, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1116 # TODO(mdan): Push this block higher in tf.function's call stack.
#    1117 try:
# -> 1118   return autograph.converted_call(
#    1119       original_func,
#    1120       args,
#    1121       kwargs,
#    1122       options=autograph.ConversionOptions(
#    1123           recursive=True,
#    1124           optional_features=autograph_options,
#    1125           user_requested=True,
#    1126       ))
#    1127 except Exception as e:  # pylint:disable=broad-except
#    1128   if hasattr(e, "ag_error_metadata"):
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:445, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     443 try:
#     444   if kwargs is not None:
# --> 445     result = converted_f(*effective_args, **kwargs)
#     446   else:
#     447     result = converted_f(*effective_args)
#
# File /tmp/__autograph_generated_filew11960or.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:383, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     380   return _call_unconverted(f, args, kwargs, options)
#     382 if not options.user_requested and conversion.is_allowlisted(f):
# --> 383   return _call_unconverted(f, args, kwargs, options)
#     385 # internal_convert_user_code is for example turned off when issuing a dynamic
#     386 # call conversion from generated code while in nonrecursive mode. In that
#     387 # case we evidently don't want to recurse, but we still have to convert
#     388 # things like builtins.
#     389 if not options.internal_convert_user_code:
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:465, in _call_unconverted(f, args, kwargs, options, update_cache)
#     463 if kwargs is not None:
#     464   return f(*args, **kwargs)
# --> 465 return f(*args)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/keras/engine/training.py:867, in Model.make_train_function.<locals>.step_function(model, iterator)
#     864   return outputs
#     866 data = next(iterator)
# --> 867 outputs = model.distribute_strategy.run(run_step, args=(data,))
#     868 outputs = reduce_per_replica(
#     869     outputs, self.distribute_strategy, reduction='first')
#     870 write_scalar_summaries(outputs, step=model._train_counter)  # pylint: disable=protected-access
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:1316, in StrategyBase.run(***failed resolving arguments***)
#    1311 with self.scope():
#    1312   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1313   # applied when the caller is also in Eager mode.
#    1314   fn = autograph.tf_convert(
#    1315       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1316   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2892, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2890   kwargs = {}
#    2891 with self._container_strategy().scope():
# -> 2892   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:3695, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3693 def _call_for_each_replica(self, fn, args, kwargs):
#    3694   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3695     return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:696, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     694 try:
#     695   with conversion_ctx:
# --> 696     return converted_call(f, args, kwargs, options=options)
#     697 except Exception as e:  # pylint:disable=broad-except
#     698   if hasattr(e, 'ag_error_metadata'):
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:383, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     380   return _call_unconverted(f, args, kwargs, options)
#     382 if not options.user_requested and conversion.is_allowlisted(f):
# --> 383   return _call_unconverted(f, args, kwargs, options)
#     385 # internal_convert_user_code is for example turned off when issuing a dynamic
#     386 # call conversion from generated code while in nonrecursive mode. In that
#     387 # case we evidently don't want to recurse, but we still have to convert
#     388 # things like builtins.
#     389 if not options.internal_convert_user_code:
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:464, in _call_unconverted(f, args, kwargs, options, update_cache)
#     461   return f.__self__.call(args, kwargs)
#     463 if kwargs is not None:
# --> 464   return f(*args, **kwargs)
#     465 return f(*args)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/keras/engine/training.py:860, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#     859 def run_step(data):
# --> 860   outputs = model.train_step(data)
#     861   # Ensure counter is updated only if `train_step` succeeds.
#     862   with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:910, in Function.__call__(self, *args, **kwds)
#     907 compiler = "xla" if self._jit_compile else "nonXla"
#     909 with OptionalXlaContext(self._jit_compile):
# --> 910   result = self._call(*args, **kwds)
#     912 new_tracing_count = self.experimental_get_tracing_count()
#     913 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:958, in Function._call(self, *args, **kwds)
#     955 try:
#     956   # This is the first call of __call__, so we have to initialize.
#     957   initializers = []
# --> 958   self._initialize(args, kwds, add_initializers_to=initializers)
#     959 finally:
#     960   # At this point we know that the initialization is complete (or less
#     961   # interestingly an exception was raised) so we no longer need a lock.
#     962   self._lock.release()
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:780, in Function._initialize(self, args, kwds, add_initializers_to)
#     777 self._lifted_initializer_graph = lifted_initializer_graph
#     778 self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     779 self._concrete_stateful_fn = (
# --> 780     self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     781         *args, **kwds))
#     783 def invalid_creator_scope(*unused_args, **unused_kwds):
#     784   """Disables variable creation."""
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/function.py:3157, in Function._get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3155   args, kwargs = None, None
#    3156 with self._lock:
# -> 3157   graph_function, _ = self._maybe_define_function(args, kwargs)
#    3158 return graph_function
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/function.py:3557, in Function._maybe_define_function(self, args, kwargs)
#    3553   return self._define_function_with_shape_relaxation(
#    3554       args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3556 self._function_cache.missed.add(call_context_key)
# -> 3557 graph_function = self._create_graph_function(args, kwargs)
#    3558 self._function_cache.primary[cache_key] = graph_function
#    3560 return graph_function, filtered_flat_args
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/function.py:3392, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3387 missing_arg_names = [
#    3388     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    3389 ]
#    3390 arg_names = base_arg_names + missing_arg_names
#    3391 graph_function = ConcreteFunction(
# -> 3392     func_graph_module.func_graph_from_py_func(
#    3393         self._name,
#    3394         self._python_function,
#    3395         args,
#    3396         kwargs,
#    3397         self.input_signature,
#    3398         autograph=self._autograph,
#    3399         autograph_options=self._autograph_options,
#    3400         arg_names=arg_names,
#    3401         override_flat_arg_shapes=override_flat_arg_shapes,
#    3402         capture_by_value=self._capture_by_value),
#    3403     self._function_attributes,
#    3404     function_spec=self.function_spec,
#    3405     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    3406     # scope. This is not the default behavior since it gets used in some
#    3407     # places (like Keras) where the FuncGraph lives longer than the
#    3408     # ConcreteFunction.
#    3409     shared_func_graph=False)
#    3410 return graph_function
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py:1143, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1140 else:
#    1141   _, original_func = tf_decorator.unwrap(python_func)
# -> 1143 func_outputs = python_func(*func_args, **func_kwargs)
#    1145 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1146 # TensorArrays and `None`s.
#    1147 func_outputs = nest.map_structure(convert, func_outputs,
#    1148                                   expand_composites=True)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:672, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     668 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     669   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     670   # the function a weak reference to itself to avoid a reference cycle.
#     671   with OptionalXlaContext(compile_with_xla):
# --> 672     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673   return out
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/function.py:4095, in class_method_to_instance_method.<locals>.bound_method_wrapper(*args, **kwargs)
#    4090   return wrapped_fn(weak_instance(), *args, **kwargs)
#    4092 # If __wrapped__ was replaced, then it is always an unbound function.
#    4093 # However, the replacer is still responsible for attaching self properly.
#    4094 # TODO(mdan): Is it possible to do it here instead?
# -> 4095 return wrapped_fn(*args, **kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py:1118, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1116 # TODO(mdan): Push this block higher in tf.function's call stack.
#    1117 try:
# -> 1118   return autograph.converted_call(
#    1119       original_func,
#    1120       args,
#    1121       kwargs,
#    1122       options=autograph.ConversionOptions(
#    1123           recursive=True,
#    1124           optional_features=autograph_options,
#    1125           user_requested=True,
#    1126       ))
#    1127 except Exception as e:  # pylint:disable=broad-except
#    1128   if hasattr(e, "ag_error_metadata"):
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:445, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     443 try:
#     444   if kwargs is not None:
# --> 445     result = converted_f(*effective_args, **kwargs)
#     446   else:
#     447     result = converted_f(*effective_args)
#
# File /tmp/__autograph_generated_file0x4hve6p.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_step(self, values)
#      13 ag__.converted_call(ag__.ld(cond).set_shape, ((ag__.ld(self)._batch_size, ag__.ld(cond).shape[1]),), None, fscope)
#      14 with ag__.ld(tf).GradientTape() as tape:
# ---> 15     loss = ag__.converted_call(ag__.ld(self).log_loss, (ag__.ld(data), ag__.ld(cond)), None, fscope)
#      16 g = ag__.converted_call(ag__.ld(tape).gradient, (ag__.ld(loss), ag__.ld(self).trainable_variables), None, fscope)
#      17 ag__.converted_call(ag__.ld(self).optimizer.apply_gradients, (ag__.converted_call(ag__.ld(zip), (ag__.ld(g), ag__.ld(self).trainable_variables), None, fscope),), None, fscope)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:383, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     380   return _call_unconverted(f, args, kwargs, options)
#     382 if not options.user_requested and conversion.is_allowlisted(f):
# --> 383   return _call_unconverted(f, args, kwargs, options)
#     385 # internal_convert_user_code is for example turned off when issuing a dynamic
#     386 # call conversion from generated code while in nonrecursive mode. In that
#     387 # case we evidently don't want to recurse, but we still have to convert
#     388 # things like builtins.
#     389 if not options.internal_convert_user_code:
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:465, in _call_unconverted(f, args, kwargs, options, update_cache)
#     463 if kwargs is not None:
#     464   return f(*args, **kwargs)
# --> 465 return f(*args)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:910, in Function.__call__(self, *args, **kwds)
#     907 compiler = "xla" if self._jit_compile else "nonXla"
#     909 with OptionalXlaContext(self._jit_compile):
# --> 910   result = self._call(*args, **kwds)
#     912 new_tracing_count = self.experimental_get_tracing_count()
#     913 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:958, in Function._call(self, *args, **kwds)
#     955 try:
#     956   # This is the first call of __call__, so we have to initialize.
#     957   initializers = []
# --> 958   self._initialize(args, kwds, add_initializers_to=initializers)
#     959 finally:
#     960   # At this point we know that the initialization is complete (or less
#     961   # interestingly an exception was raised) so we no longer need a lock.
#     962   self._lock.release()
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:780, in Function._initialize(self, args, kwds, add_initializers_to)
#     777 self._lifted_initializer_graph = lifted_initializer_graph
#     778 self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     779 self._concrete_stateful_fn = (
# --> 780     self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     781         *args, **kwds))
#     783 def invalid_creator_scope(*unused_args, **unused_kwds):
#     784   """Disables variable creation."""
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/function.py:3157, in Function._get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3155   args, kwargs = None, None
#    3156 with self._lock:
# -> 3157   graph_function, _ = self._maybe_define_function(args, kwargs)
#    3158 return graph_function
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/function.py:3557, in Function._maybe_define_function(self, args, kwargs)
#    3553   return self._define_function_with_shape_relaxation(
#    3554       args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3556 self._function_cache.missed.add(call_context_key)
# -> 3557 graph_function = self._create_graph_function(args, kwargs)
#    3558 self._function_cache.primary[cache_key] = graph_function
#    3560 return graph_function, filtered_flat_args
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/function.py:3392, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3387 missing_arg_names = [
#    3388     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    3389 ]
#    3390 arg_names = base_arg_names + missing_arg_names
#    3391 graph_function = ConcreteFunction(
# -> 3392     func_graph_module.func_graph_from_py_func(
#    3393         self._name,
#    3394         self._python_function,
#    3395         args,
#    3396         kwargs,
#    3397         self.input_signature,
#    3398         autograph=self._autograph,
#    3399         autograph_options=self._autograph_options,
#    3400         arg_names=arg_names,
#    3401         override_flat_arg_shapes=override_flat_arg_shapes,
#    3402         capture_by_value=self._capture_by_value),
#    3403     self._function_attributes,
#    3404     function_spec=self.function_spec,
#    3405     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    3406     # scope. This is not the default behavior since it gets used in some
#    3407     # places (like Keras) where the FuncGraph lives longer than the
#    3408     # ConcreteFunction.
#    3409     shared_func_graph=False)
#    3410 return graph_function
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py:1143, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1140 else:
#    1141   _, original_func = tf_decorator.unwrap(python_func)
# -> 1143 func_outputs = python_func(*func_args, **func_kwargs)
#    1145 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1146 # TensorArrays and `None`s.
#    1147 func_outputs = nest.map_structure(convert, func_outputs,
#    1148                                   expand_composites=True)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:672, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     668 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     669   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     670   # the function a weak reference to itself to avoid a reference cycle.
#     671   with OptionalXlaContext(compile_with_xla):
# --> 672     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673   return out
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/function.py:4095, in class_method_to_instance_method.<locals>.bound_method_wrapper(*args, **kwargs)
#    4090   return wrapped_fn(weak_instance(), *args, **kwargs)
#    4092 # If __wrapped__ was replaced, then it is always an unbound function.
#    4093 # However, the replacer is still responsible for attaching self properly.
#    4094 # TODO(mdan): Is it possible to do it here instead?
# -> 4095 return wrapped_fn(*args, **kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py:1118, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1116 # TODO(mdan): Push this block higher in tf.function's call stack.
#    1117 try:
# -> 1118   return autograph.converted_call(
#    1119       original_func,
#    1120       args,
#    1121       kwargs,
#    1122       options=autograph.ConversionOptions(
#    1123           recursive=True,
#    1124           optional_features=autograph_options,
#    1125           user_requested=True,
#    1126       ))
#    1127 except Exception as e:  # pylint:disable=broad-except
#    1128   if hasattr(e, "ag_error_metadata"):
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:445, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     443 try:
#     444   if kwargs is not None:
# --> 445     result = converted_f(*effective_args, **kwargs)
#     446   else:
#     447     result = converted_f(*effective_args)
#
# File /tmp/__autograph_generated_file1jn6mio7.py:10, in outer_factory.<locals>.inner_factory.<locals>.tf__log_loss(self, _x, _c)
#       8 do_return = False
#       9 retval_ = ag__.UndefinedReturnValue()
# ---> 10 loss = (- ag__.converted_call(ag__.ld(tf).reduce_mean, (ag__.converted_call(ag__.ld(self).flow.log_prob, (ag__.ld(_x),), dict(bijector_kwargs=ag__.converted_call(ag__.ld(make_bijector_kwargs), (ag__.ld(self).flow.bijector, {'bijector.': {'conditional_input': ag__.ld(_c)}}), None, fscope)), fscope),), None, fscope))
#      11 try:
#      12     do_return = True
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:337, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     335 if conversion.is_in_allowlist_cache(f, options):
#     336   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 337   return _call_unconverted(f, args, kwargs, options, False)
#     339 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     340   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:464, in _call_unconverted(f, args, kwargs, options, update_cache)
#     461   return f.__self__.call(args, kwargs)
#     463 if kwargs is not None:
# --> 464   return f(*args, **kwargs)
#     465 return f(*args)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/distributions/distribution.py:1316, in Distribution.log_prob(self, value, name, **kwargs)
#    1304 def log_prob(self, value, name='log_prob', **kwargs):
#    1305   """Log probability density/mass function.
#    1306
#    1307   Args:
#    (...)
#    1314       values of type `self.dtype`.
#    1315   """
# -> 1316   return self._call_log_prob(value, name, **kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/distributions/distribution.py:1298, in Distribution._call_log_prob(self, value, name, **kwargs)
#    1296 with self._name_and_control_scope(name, value, kwargs):
#    1297   if hasattr(self, '_log_prob'):
# -> 1298     return self._log_prob(value, **kwargs)
#    1299   if hasattr(self, '_prob'):
#    1300     return tf.math.log(self._prob(value, **kwargs))
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/distributions/transformed_distribution.py:361, in TransformedDistribution._log_prob(self, y, **kwargs)
#     357 distribution_kwargs, bijector_kwargs = self._kwargs_split_fn(kwargs)
#     359 # For caching to work, it is imperative that the bijector is the first to
#     360 # modify the input.
# --> 361 x = self.bijector.inverse(y, **bijector_kwargs)
#     362 event_ndims = tf.nest.map_structure(
#     363     ps.rank_from_shape,
#     364     self._event_shape_tensor(),
#     365     self.event_shape)
#     367 ildj = self.bijector.inverse_log_det_jacobian(
#     368     y, event_ndims=event_ndims, **bijector_kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/bijector.py:1431, in Bijector.inverse(self, y, name, **kwargs)
#    1413 def inverse(self, y, name='inverse', **kwargs):
#    1414   """Returns the inverse `Bijector` evaluation, i.e., X = g^{-1}(Y).
#    1415
#    1416   Args:
#    (...)
#    1429     NotImplementedError: if `_inverse` is not implemented.
#    1430   """
# -> 1431   return self._call_inverse(y, name, **kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/bijector.py:1411, in Bijector._call_inverse(self, y, name, **kwargs)
#    1409 if not self._is_injective:  # No caching for non-injective
#    1410   return self._inverse(y, **kwargs)
# -> 1411 return self._cache.inverse(y, **kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/internal/cache_util.py:347, in BijectorCache.inverse(self, y, **kwargs)
#     336 def inverse(self, y, **kwargs):
#     337   """Invokes the 'inverse' transformation, or looks up previous results.
#     338
#     339   Args:
#    (...)
#     345     The output of the bijector's `_inverse` method, or a cached result.
#     346   """
# --> 347   return self._lookup(y, self._inverse_name, self._forward_name, **kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/internal/cache_util.py:493, in BijectorCache._lookup(self, input, forward_name, inverse_name, **kwargs)
#     487   output = output_ref()
#     488 else:
#     489   # Get the output structure, and declare a
#     490   # weakref to clear it from the cache once it gets GCed
#     491   output = nest.map_structure(
#     492       _containerize,
# --> 493       self._invoke(input, forward_name, kwargs, attrs))
#     494   output_ref = WeakStructRef(
#     495       output,
#     496       subkey=(self.bijector, self.bijector_class, inverse_name, kwargs),
#     497       callback=self.storage.maybe_del)
#     498   # Set the input->output mapping.
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/internal/cache_util.py:532, in BijectorCache._invoke(self, input, fn_name, kwargs, attributes)
#     530 def _invoke(self, input, fn_name, kwargs, attributes):  # pylint: disable=unused-argument
#     531   """Invokes the wrapped function. Override to customize behavior."""
# --> 532   return getattr(self.bijector, fn_name)(input, **kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/composition.py:614, in Composition._inverse(self, y, **kwargs)
#     610 if not self._is_injective:  # pylint: disable=protected-access
#     611   raise NotImplementedError(
#     612       'Invert is not implemented for compositions of '
#     613       'non-injective bijectors.')
# --> 614 return self._call_walk_inverse(
#     615     lambda b, y, **kwargs: b.inverse(y, **kwargs),
#     616     y, **kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/composition.py:352, in Composition._call_walk_inverse(self, step_fn, *args, **kwargs)
#     348 args = tuple(nest_util.coerce_structure(self.inverse_min_event_ndims, y)
#     349              for y in args)
#     351 if len(args) == 1:
# --> 352   return self._walk_inverse(step_fn, *args, **kwargs)
#     354 # Convert a tuple of structures to a structure of tuples. This
#     355 # allows `_walk` methods to route aligned structures of inputs/outputs
#     356 # independently, obviates the need for conditional tuple unpacking.
#     357 packed_args = pack_structs_like(self.inverse_min_event_ndims, *args)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/chain.py:148, in _Chain._walk_inverse(self, step_fn, y, **kwargs)
#     146 """Applies `transform_fn` to `y` sequentially over nested bijectors."""
#     147 for bij in self._bijectors:
# --> 148   y = step_fn(bij, y, **kwargs.get(bij.name, {}))
#     149 return y
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/composition.py:615, in Composition._inverse.<locals>.<lambda>(b, y, **kwargs)
#     610 if not self._is_injective:  # pylint: disable=protected-access
#     611   raise NotImplementedError(
#     612       'Invert is not implemented for compositions of '
#     613       'non-injective bijectors.')
#     614 return self._call_walk_inverse(
# --> 615     lambda b, y, **kwargs: b.inverse(y, **kwargs),
#     616     y, **kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/bijector.py:1431, in Bijector.inverse(self, y, name, **kwargs)
#    1413 def inverse(self, y, name='inverse', **kwargs):
#    1414   """Returns the inverse `Bijector` evaluation, i.e., X = g^{-1}(Y).
#    1415
#    1416   Args:
#    (...)
#    1429     NotImplementedError: if `_inverse` is not implemented.
#    1430   """
# -> 1431   return self._call_inverse(y, name, **kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/bijector.py:1411, in Bijector._call_inverse(self, y, name, **kwargs)
#    1409 if not self._is_injective:  # No caching for non-injective
#    1410   return self._inverse(y, **kwargs)
# -> 1411 return self._cache.inverse(y, **kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/internal/cache_util.py:347, in BijectorCache.inverse(self, y, **kwargs)
#     336 def inverse(self, y, **kwargs):
#     337   """Invokes the 'inverse' transformation, or looks up previous results.
#     338
#     339   Args:
#    (...)
#     345     The output of the bijector's `_inverse` method, or a cached result.
#     346   """
# --> 347   return self._lookup(y, self._inverse_name, self._forward_name, **kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/internal/cache_util.py:493, in BijectorCache._lookup(self, input, forward_name, inverse_name, **kwargs)
#     487   output = output_ref()
#     488 else:
#     489   # Get the output structure, and declare a
#     490   # weakref to clear it from the cache once it gets GCed
#     491   output = nest.map_structure(
#     492       _containerize,
# --> 493       self._invoke(input, forward_name, kwargs, attrs))
#     494   output_ref = WeakStructRef(
#     495       output,
#     496       subkey=(self.bijector, self.bijector_class, inverse_name, kwargs),
#     497       callback=self.storage.maybe_del)
#     498   # Set the input->output mapping.
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/internal/cache_util.py:566, in BijectorCacheWithGreedyAttrs._invoke(self, input, fn_name, kwargs, attributes)
#     564 def _invoke(self, input, fn_name, kwargs, attributes):  # pylint: disable=redefined-builtin
#     565   # Update `attributes` with the attrs returned by `_func`.
# --> 566   output, greedy_attrs = getattr(self.bijector, fn_name)(input, **kwargs)
#     567   if greedy_attrs is not None:
#     568     attributes.update(greedy_attrs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/ffjord.py:374, in FFJORD._augmented_inverse(self, y, **condition_kwargs)
#     372 augmented_y = (y, tf.zeros_like(y))
#     373 if condition_kwargs:
# --> 374   x, ildj = self._solve_ode(augmented_inv_ode_fn, augmented_y,
#     375                             constants=condition_kwargs)
#     376 else:
#     377   x, ildj = self._solve_ode(augmented_inv_ode_fn, augmented_y)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/ffjord.py:346, in FFJORD._solve_ode(self, ode_fn, state, **kwargs)
#     334 def _solve_ode(self, ode_fn, state, **kwargs):
#     335   """Solves the initial value problem defined by `ode_fn`.
#     336
#     337   Args:
#    (...)
#     344       the solution of ODE defined by `ode_fn` at `self._final_time`.
#     345   """
# --> 346   integration_result = self._ode_solve_fn(
#     347       ode_fn=ode_fn,
#     348       initial_time=self._initial_time,
#     349       initial_state=state,
#     350       solution_times=[self._final_time],
#     351       **kwargs)
#     352   final_state = tf.nest.map_structure(
#     353       lambda x: x[-1], integration_result.states)
#     354   return final_state
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/math/ode/base.py:480, in Solver.solve(self, ode_fn, initial_time, initial_state, solution_times, jacobian_fn, jacobian_sparsity, batch_ndims, previous_solver_internal_state, constants)
#     477 # TODO(b/140760650): We must use a resource-using variable scope, otherwise
#     478 # custom_gradient will complain even if there are no variables in `ode_fn`.
#     479 with tf1.variable_scope(tf1.get_variable_scope(), use_resource=True):
# --> 480   return gradient_helper(initial_state, constants)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/internal/custom_gradient.py:113, in custom_gradient.<locals>.finalize.<locals>.none_wrapper(*args, **kwargs)
#     109       return result
#     111   return val, vjp_bwd_wrapped
# --> 113 return f_wrapped(*trimmed_args, **kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/ops/custom_gradient.py:342, in Bind.__call__(self, *a, **k)
#     341 def __call__(self, *a, **k):
# --> 342   return self._d(self._f, a, k)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/ops/custom_gradient.py:298, in custom_gradient.<locals>.decorated(wrapped, args, kwargs)
#     296   return _eager_mode_decorator(wrapped, args, kwargs)
#     297 else:
# --> 298   return _graph_mode_decorator(wrapped, args, kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/ops/custom_gradient.py:423, in _graph_mode_decorator(f, args, kwargs)
#     418 before_vars = set([
#     419     v.ref() for v in current_var_scope.global_variables() +
#     420     current_var_scope.local_variables()
#     421 ])
#     422 with tape_lib.VariableWatcher() as variable_watcher:
# --> 423   result, grad_fn = f(*args)
#     425 args = nest.flatten(args)
#     426 flat_result = nest.flatten(result)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/internal/custom_gradient.py:89, in custom_gradient.<locals>.finalize.<locals>.none_wrapper.<locals>.f_wrapped(*args, **kwargs)
#      87     reconstruct_args.append(args[0])
#      88     args = args[1:]
# ---> 89 val, aux = vjp_fwd(*reconstruct_args, **kwargs)
#      91 def vjp_bwd_wrapped(*g, **kwargs):
#      92   # We don't want to use an explicit `variables` arg, because TF will
#      93   # complain if the wrapped function doesn't actually have variables
#      94   # in it. TF will only specify this arg if there are variables.
#      95   variables = kwargs.get('variables', ())
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/math/ode/base.py:222, in Solver.solve.<locals>.vjp_fwd(initial_state, constants)
#     221 def vjp_fwd(initial_state, constants):
# --> 222   results = self._solve(
#     223       ode_fn=functools.partial(ode_fn, **constants),
#     224       initial_time=initial_time,
#     225       initial_state=initial_state,
#     226       solution_times=solution_times,
#     227       jacobian_fn=jacobian_fn,
#     228       jacobian_sparsity=jacobian_sparsity,
#     229       batch_ndims=batch_ndims,
#     230       previous_solver_internal_state=previous_solver_internal_state,
#     231   )
#     232   results = Results(
#     233       times=tf.stop_gradient(results.times),
#     234       states=results.states,
#    (...)
#     237       solver_internal_state=util.stop_gradient_of_real_or_complex_entries(
#     238           results.solver_internal_state))
#     239   return results, (results, constants)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/math/ode/dormand_prince.py:288, in DormandPrince._solve(***failed resolving arguments***)
#     283   def iterate_cond(time_id, *_):
#     284     return time_id < num_solution_times
#     286   [
#     287       _, solver_internal_state, diagnostics, solutions_arrays
# --> 288   ] = tf.while_loop(iterate_cond, advance_to_solution_time, [
#     289       0, solver_internal_state, diagnostics, solutions_arrays
#     290   ])
#     292 times = times_array.stack()
#     293 stack_components = lambda x: x.stack()
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:620, in deprecated_arg_values.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     613           _PRINTED_WARNING[(func, arg_name)] = True
#     614         logging.warning(
#     615             'From %s: calling %s (from %s) with %s=%s is deprecated and '
#     616             'will be removed %s.\nInstructions for updating:\n%s',
#     617             _call_location(), decorator_utils.get_qualified_name(func),
#     618             func.__module__, arg_name, arg_value, 'in a future version'
#     619             if date is None else ('after %s' % date), instructions)
# --> 620 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/ops/control_flow_ops.py:2548, in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#    2372 @tf_export("while_loop", v1=[])
#    2373 @deprecation.deprecated_arg_values(
#    2374     None,
#    (...)
#    2389                   maximum_iterations=None,
#    2390                   name=None):
#    2391   """Repeat `body` while the condition `cond` is true.
#    2392
#    2393   `cond` is a callable returning a boolean scalar tensor. `body` is a callable
#    (...)
#    2546
#    2547   """
# -> 2548   return while_loop(
#    2549       cond=cond,
#    2550       body=body,
#    2551       loop_vars=loop_vars,
#    2552       shape_invariants=shape_invariants,
#    2553       parallel_iterations=parallel_iterations,
#    2554       back_prop=back_prop,
#    2555       swap_memory=swap_memory,
#    2556       name=name,
#    2557       maximum_iterations=maximum_iterations,
#    2558       return_same_structure=True)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/ops/control_flow_ops.py:2746, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2743 executing_eagerly = context.executing_eagerly()
#    2744 if (util.EnableControlFlowV2(ops.get_default_graph()) and
#    2745     not executing_eagerly):
# -> 2746   return while_v2.while_loop(
#    2747       cond,
#    2748       body,
#    2749       loop_vars,
#    2750       shape_invariants=shape_invariants,
#    2751       parallel_iterations=parallel_iterations,
#    2752       maximum_iterations=maximum_iterations,
#    2753       name=name,
#    2754       return_same_structure=return_same_structure,
#    2755       back_prop=back_prop)
#    2757 with ops.name_scope(name, "while", loop_vars):
#    2758   if not loop_vars:
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/ops/while_v2.py:214, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, maximum_iterations, name, return_same_structure, back_prop)
#     210   # TODO(srbs): Update lowering code to create _Enter nodes with
#     211   # is_constant=True for inputs that are directly passed to outputs.
#     212   return [loop_counter + 1, maximum_iterations_arg] + list(outputs)
# --> 214 body_graph = func_graph_module.func_graph_from_py_func(
#     215     body_name,
#     216     wrapped_body,
#     217     [],  # We provide signature instead of args.
#     218     {},
#     219     signature=signature,
#     220     func_graph=util.WhileBodyFuncGraph(
#     221         body_name, collections=ops.get_default_graph()._collections),  # pylint: disable=protected-access
#     222     add_control_dependencies=add_control_dependencies,
#     223     acd_record_initial_resource_uses=stateful_parallelism)
#     224 # Add external captures of body to the list of loop vars.
#     225 # Note that external tensors will be treated as loop invariants, i.e.,
#     226 # the value of that tensor in each iteration is the same as it was at the
#     227 # beginning of the loop execution.
#     228 deferred_external_captures = nest.flatten(
#     229     [c() for c in body_graph.deferred_external_captures],
#     230     expand_composites=True)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py:1143, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1140 else:
#    1141   _, original_func = tf_decorator.unwrap(python_func)
# -> 1143 func_outputs = python_func(*func_args, **func_kwargs)
#    1145 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
# ...
#    2374     None,
#    (...)
#    2389                   maximum_iterations=None,
#    2390                   name=None):
#    2391   """Repeat `body` while the condition `cond` is true.
#    2392
#    2393   `cond` is a callable returning a boolean scalar tensor. `body` is a callable
#    (...)
#    2546
#    2547   """
# -> 2548   return while_loop(
#    2549       cond=cond,
#    2550       body=body,
#    2551       loop_vars=loop_vars,
#    2552       shape_invariants=shape_invariants,
#    2553       parallel_iterations=parallel_iterations,
#    2554       back_prop=back_prop,
#    2555       swap_memory=swap_memory,
#    2556       name=name,
#    2557       maximum_iterations=maximum_iterations,
#    2558       return_same_structure=True)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/ops/control_flow_ops.py:2746, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2743 executing_eagerly = context.executing_eagerly()
#    2744 if (util.EnableControlFlowV2(ops.get_default_graph()) and
#    2745     not executing_eagerly):
# -> 2746   return while_v2.while_loop(
#    2747       cond,
#    2748       body,
#    2749       loop_vars,
#    2750       shape_invariants=shape_invariants,
#    2751       parallel_iterations=parallel_iterations,
#    2752       maximum_iterations=maximum_iterations,
#    2753       name=name,
#    2754       return_same_structure=return_same_structure,
#    2755       back_prop=back_prop)
#    2757 with ops.name_scope(name, "while", loop_vars):
#    2758   if not loop_vars:
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/ops/while_v2.py:214, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, maximum_iterations, name, return_same_structure, back_prop)
#     210   # TODO(srbs): Update lowering code to create _Enter nodes with
#     211   # is_constant=True for inputs that are directly passed to outputs.
#     212   return [loop_counter + 1, maximum_iterations_arg] + list(outputs)
# --> 214 body_graph = func_graph_module.func_graph_from_py_func(
#     215     body_name,
#     216     wrapped_body,
#     217     [],  # We provide signature instead of args.
#     218     {},
#     219     signature=signature,
#     220     func_graph=util.WhileBodyFuncGraph(
#     221         body_name, collections=ops.get_default_graph()._collections),  # pylint: disable=protected-access
#     222     add_control_dependencies=add_control_dependencies,
#     223     acd_record_initial_resource_uses=stateful_parallelism)
#     224 # Add external captures of body to the list of loop vars.
#     225 # Note that external tensors will be treated as loop invariants, i.e.,
#     226 # the value of that tensor in each iteration is the same as it was at the
#     227 # beginning of the loop execution.
#     228 deferred_external_captures = nest.flatten(
#     229     [c() for c in body_graph.deferred_external_captures],
#     230     expand_composites=True)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py:1143, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1140 else:
#    1141   _, original_func = tf_decorator.unwrap(python_func)
# -> 1143 func_outputs = python_func(*func_args, **func_kwargs)
#    1145 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1146 # TensorArrays and `None`s.
#    1147 func_outputs = nest.map_structure(convert, func_outputs,
#    1148                                   expand_composites=True)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/ops/while_v2.py:200, in while_loop.<locals>.wrapped_body(loop_counter, maximum_iterations_arg, *args)
#     193   ops.get_default_graph().capture(t)
#     195 # Convert the flow variables in `args` to TensorArrays. `args` should
#     196 # already have the same structure as `orig_loop_vars` but currently there
#     197 # is no nest.zip so we call `_pack_sequence_as` which flattens both
#     198 # `orig_loop_vars` and `args`, converts flows in `args` to TensorArrays
#     199 # and packs it into the structure of `orig_loop_vars`.
# --> 200 outputs = body(*_pack_sequence_as(orig_loop_vars, args))
#     201 if not nest.is_sequence_or_composite(outputs):
#     202   outputs = [outputs]
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/math/ode/dormand_prince.py:409, in DormandPrince._step(self, solver_state, diagnostics, max_ode_fn_evals, ode_fn, atol, rtol, safety, ifactor, dfactor)
#     407 max_y_vals = tf.nest.map_structure(tf.math.maximum, abs_y0, abs_y1)
#     408 ones_nest = rk_util.nest_constant(abs_y0)
# --> 409 error_tol = rk_util.weighted_sum([atol, rtol], [ones_nest, max_y_vals])
#     410 def scale_errors(error_component, tol_scale):
#     411   abs_square_error = rk_util.abs_square(error_component)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/math/ode/runge_kutta_util.py:77, in weighted_sum(weights, list_of_states)
#      75   tf.nest.assert_same_structure(state, list_of_states[-1])
#      76 weights_and_states = zip(weights, list_of_states)
# ---> 77 weighted_states = [
#      78     [tf.cast(w, s_comp.dtype) * s_comp for s_comp in tf.nest.flatten(s)]
#      79     for w, s in weights_and_states if _possibly_nonzero(w)
#      80 ]
#      81 list_of_components = zip(*weighted_states)  # Put same components together.
#      82 flat_final_state = [tf.add_n(component) for component in list_of_components]
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/math/ode/runge_kutta_util.py:78, in <listcomp>(.0)
#      75   tf.nest.assert_same_structure(state, list_of_states[-1])
#      76 weights_and_states = zip(weights, list_of_states)
#      77 weighted_states = [
# ---> 78     [tf.cast(w, s_comp.dtype) * s_comp for s_comp in tf.nest.flatten(s)]
#      79     for w, s in weights_and_states if _possibly_nonzero(w)
#      80 ]
#      81 list_of_components = zip(*weighted_states)  # Put same components together.
#      82 flat_final_state = [tf.add_n(component) for component in list_of_components]
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/math/ode/runge_kutta_util.py:78, in <listcomp>(.0)
#      75   tf.nest.assert_same_structure(state, list_of_states[-1])
#      76 weights_and_states = zip(weights, list_of_states)
#      77 weighted_states = [
# ---> 78     [tf.cast(w, s_comp.dtype) * s_comp for s_comp in tf.nest.flatten(s)]
#      79     for w, s in weights_and_states if _possibly_nonzero(w)
#      80 ]
#      81 list_of_components = zip(*weighted_states)  # Put same components together.
#      82 flat_final_state = [tf.add_n(component) for component in list_of_components]
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/ops/math_ops.py:1383, in _OverrideBinaryOperatorHelper.<locals>.binary_op_wrapper(x, y)
#    1378 try:
#    1379   # force_same_dtype=False to preserve existing TF behavior
#    1380   # TODO(b/178860388): Figure out why binary_op_wrapper and
#    1381   #   r_binary_op_wrapper use different force_same_dtype values.
#    1382   x, y = maybe_promote_tensors(x, y, force_same_dtype=False)
# -> 1383   return func(x, y, name=name)
#    1384 except (TypeError, ValueError) as e:
#    1385   # Even if dispatching the op failed, the RHS may be a tensor aware
#    1386   # object that can implement the operator with knowledge of itself
#    (...)
#    1389   # original error from the LHS, because it may be more
#    1390   # informative.
#    1391   if hasattr(type(y), "__r%s__" % op_name):
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/ops/math_ops.py:1747, in _mul_dispatch(x, y, name)
#    1745   return sparse_tensor.SparseTensor(y.indices, new_vals, y.dense_shape)
#    1746 else:
# -> 1747   return multiply(x, y, name=name)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1096, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1094 # Fallback dispatch system (dispatch v1):
#    1095 try:
# -> 1096   return dispatch_target(*args, **kwargs)
#    1097 except (TypeError, ValueError):
#    1098   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1099   # TypeError, when given unexpected types.  So we need to catch both.
#    1100   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/ops/math_ops.py:534, in multiply(x, y, name)
#     485 @tf_export("math.multiply", "multiply")
#     486 @dispatch.register_binary_elementwise_api
#     487 @dispatch.add_dispatch_support
#     488 def multiply(x, y, name=None):
#     489   """Returns an element-wise x * y.
#     490
#     491   For example:
#    (...)
#     531    * InvalidArgumentError: When `x` and `y` have incompatible shapes or types.
#     532   """
# --> 534   return gen_math_ops.mul(x, y, name)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/ops/gen_math_ops.py:6589, in mul(x, y, name)
#    6587     pass  # Add nodes to the TensorFlow graph.
#    6588 # Add nodes to the TensorFlow graph.
# -> 6589 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    6590       "Mul", x=x, y=y, name=name)
#    6591 _result = _outputs[:]
#    6592 if _execute.must_record_gradient():
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/op_def_library.py:744, in _apply_op_helper(op_type_name, name, **keywords)
#     739 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     740                         if arg.is_ref]
#     741 with _MaybeColocateWith(must_colocate_inputs):
#     742   # Add Op to graph
#     743   # pylint: disable=protected-access
# --> 744   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     745                              name=scope, input_types=input_types,
#     746                              attrs=attr_protos, op_def=op_def)
#     748 # `outputs` is returned as a separate return value so that the output
#     749 # tensors can the `op` per se can be decoupled so that the
#     750 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     751 # for more details.
#     752 outputs = op.outputs
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py:687, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     685   if ctxt is not None and hasattr(ctxt, "AddValue"):
#     686     inp = ctxt.AddValue(inp)
# --> 687   inp = self.capture(inp)
#     688   captured_inputs.append(inp)
#     689 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     690     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     691     compute_device)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py:741, in FuncGraph.capture(self, tensor, name, shape)
#     732       raise errors.InaccessibleTensorError(
#     733           "tf.Graph captured an external symbolic tensor. The symbolic "
#     734           f"tensor {tensor!r} is captured by {self}, but it is defined at "
#    (...)
#     738           "https://www.tensorflow.org/guide/function#all_outputs_of_a_tffunction_must_be_return_values "
#     739           "for more information.\n")
#     740     inner_graph = inner_graph.outer_graph
# --> 741   return self._capture_helper(tensor, name)
#     742 return tensor
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py:747, in FuncGraph._capture_helper(self, tensor, name, shape)
#     745 capture = self._captures.get(id(tensor))
#     746 if capture is None:
# --> 747   placeholder = _create_substitute_placeholder(
#     748       tensor, name=name, dtype=tensor.dtype, shape=shape)
#     749   # Record the composite device as an attribute to the placeholder.
#     750   # This attribute would be propogated into the arg_attr of the FunctionDef.
#     751   # Currently, a packed eager tensor is always placed on a CompositeDevice.
#     752   if isinstance(tensor, ops.EagerTensor) and tensor.is_packed:
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py:1287, in _create_substitute_placeholder(value, name, dtype, shape)
#    1285   shape = value.shape
#    1286 with ops.control_dependencies(None):
# -> 1287   placeholder = graph_placeholder(
#    1288       dtype=dtype or value.dtype, shape=shape, name=name)
#    1289 handle_data_util.copy_handle_data(value, placeholder)
#    1290 return placeholder
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/graph_only_ops.py:38, in graph_placeholder(dtype, shape, name)
#      36 g = ops.get_default_graph()
#      37 attrs = {"dtype": dtype_value, "shape": shape}
# ---> 38 op = g._create_op_internal(  # pylint: disable=protected-access
#      39     "Placeholder", [], [dtype], input_types=[],
#      40     attrs=attrs, name=name)
#      41 result, = op.outputs
#      42 if op_callbacks.should_invoke_op_callbacks():
#      43   # TODO(b/147670703): Once the special-op creation code paths
#      44   # are unified. Remove this `if` block.
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py:689, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     687   inp = self.capture(inp)
#     688   captured_inputs.append(inp)
# --> 689 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     690     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     691     compute_device)
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:3706, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3696 with self._mutation_lock():
#    3697   ret = Operation(
#    3698       node_def,
#    3699       self,
#    (...)
#    3704       original_op=self._default_original_op,
#    3705       op_def=op_def)
# -> 3706   self._create_op_helper(ret, compute_device=compute_device)
#    3707 return ret
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:3781, in Graph._create_op_helper(self, op, compute_device)
#    3778 self._record_op_seen_by_control_dependencies(op)
#    3780 if compute_device:
# -> 3781   self._apply_device_functions(op)
#    3783 # Snapshot the colocation stack metadata before we might generate error
#    3784 # messages using it.  Note that this snapshot depends on the actual stack
#    3785 # and is independent of the op's _class attribute.
#    3786 # pylint: disable=protected-access
#    3787 op._colocation_code_locations = self._snapshot_colocation_stack_metadata()
#
# File ~/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:4703, in Graph._apply_device_functions(self, op)
#    4701     op._set_device_from_string(device_string)
#    4702     prior_device_string = device_string
# -> 4703 op._device_code_locations = self._snapshot_device_function_stack_metadata()
#
# KeyboardInterrupt:

# %%
# Where in the base distribution are each of the double gaussians mapped to? 
# (Hint: draw samples from each gaussian separately and run the transformation backwards)

inversed_first = model.conditional_inverse(transformed_first, np.ones((NSAMPLES,1),dtype=np.float32))
inversed_second = model.conditional_inverse(transformed_second, np.zeros((NSAMPLES,1),dtype=np.float32))

fig2 = plt.figure(figsize=(8, 3))
plt.scatter(inversed_first[:, 0], inversed_first[:, 1], color="r")
plt.scatter(inversed_second[:, 0], inversed_second[:, 1], color="b")

# %%
# Imagine you started with a random point drawn from the 2-gaussian distribution. 
# How would you determine the conditional value this point belongs to? 
# (Hint: In the toy example, z can only assume 2 values z1, and z2, determine 
# the probability of p(x|z1) and p(x|z2))

random_point = transformed[0]
prob1 = model.conditional_prob([random_point], [[1.0]])
prob0 = model.conditional_prob([random_point], [[0.0]])
print(f"Prob1: {prob1}, Prob2: {prob0}, Random point: {random_point}")

prob1 = model.conditional_prob([random_point], [[1.0]])
prob0 = model.conditional_prob([random_point], [[0.0]])
print(f"Prob1: {prob1}, Prob2: {prob0}, Random point: {random_point}")

prob1 = model.conditional_prob([random_point], [[1.0]])
prob0 = model.conditional_prob([random_point], [[0.0]])
print(f"Prob1: {prob1}, Prob2: {prob0}, Random point: {random_point}")


# We see that the probability that Random Point belongs to the first distribution is nonzero,
# and the probability that it belongs to the second distribution is essentially 0.
# This point is at (0.076, 0.024), and is essentially at the center of the red (first)
# distribution, so our result makes sense.

# The reason why calling conditional_prob() many times gives different answers is that
# we are using an approximation to the trace. If we used the slower and exact function,
# then it would be deterministic.
# Out:
# Prob1: [0.74297625], Prob2: [3.7555317e-05], Random point: [0.07565676 0.02377819]
# Prob1: [0.33040854], Prob2: [6.666122e-05], Random point: [0.07565676 0.02377819]
# Prob1: [1.1889745], Prob2: [3.9869148e-05], Random point: [0.07565676 0.02377819]

# %%
model.flow
# Out:
# <tfp.distributions.TransformedDistribution 'chain_of_bijector3_of_bijector2_of_bijector1_of_bijector0MultivariateNormalDiag' batch_shape=[] event_shape=[2] dtype=float32>
